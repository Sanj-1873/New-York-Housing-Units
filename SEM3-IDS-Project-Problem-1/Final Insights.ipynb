# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks", color_codes=True)

# %%
df = pd.read_csv('dataset.csv')
print(df.columns)

#print(df.council_district.head(5))
cd = df.council_district.unique().tolist()
print(cd)
# Out:
# Index(['Unnamed: 0', 'project_id', 'project_name', 'project_start_date',
#        'project_completion_date', 'building_id', 'number', 'street', 'borough',
#        'postcode', 'bbl', 'bin', 'community_board', 'council_district',
#        'census_tract', 'nta_-_neighborhood_tabulation_area', 'latitude',
#        'longitude', 'latitude_internal', 'longitude_internal',
#        'building_completion_date', 'reporting_construction_type',
#        'extended_affordability_only', 'prevailing_wage_status',
#        'extremely_low_income_units', 'very_low_income_units',
#        'low_income_units', 'moderate_income_units', 'middle_income_units',
#        'other_income_units', 'studio_units', 'br1_units', 'br2_units',
#        'br3_units', 'br4_units', 'br5_units', 'br6_units', 'unknown-br_units',
#        'counted_rental_units', 'counted_homeownership_units',
#        'all_counted_units', 'total_units'],
#       dtype='object')
# [9, 7, 34, 27, 47, 17, 48, 14, 8, 31, 2, 41, 16, 37, 43, 28, 35, 15, 5, 42, 24, 36, 11, 6, 18, 4, 40, 19, 49, 33, 26, 3, 13, 39, 45, 12, 38, 1, 32, 10, 20, 22, 21, 23, 50, 46, 44, 25]

# %%
### Distribution of Income units in each concile distict
for dit_num in cd:
    test = df.loc[df['council_district']==dit_num]
    #print(test)
    Total_e_l = test['extremely_low_income_units'].sum()
    
    Total_v_l = test['very_low_income_units'].sum()
    
    Total_l = test['low_income_units'].sum()
   
    Total_mo = test['moderate_income_units'].sum()
 
    Total_mid = test['middle_income_units'].sum()
    
    df2 = pd.DataFrame({'total': [Total_e_l, Total_v_l,Total_l,Total_mo,Total_mid]},index=['extremely_low_income_units', 'very_low_income_units','low_income_units','moderate_income_units','middle_income_units'])
    plot = df2.plot.pie(y='total', figsize=(5, 5))
    print('The distict zone we are looking at here is', dit_num)
# Out:
# The distict zone we are looking at here is 9
# The distict zone we are looking at here is 7
# The distict zone we are looking at here is 34
# The distict zone we are looking at here is 27
# The distict zone we are looking at here is 47
# The distict zone we are looking at here is 17
# The distict zone we are looking at here is 48
# The distict zone we are looking at here is 14
# The distict zone we are looking at here is 8
# The distict zone we are looking at here is 31
# The distict zone we are looking at here is 2
# The distict zone we are looking at here is 41
# The distict zone we are looking at here is 16
# The distict zone we are looking at here is 37
# The distict zone we are looking at here is 43
# The distict zone we are looking at here is 28
# The distict zone we are looking at here is 35
# The distict zone we are looking at here is 15
# The distict zone we are looking at here is 5
# The distict zone we are looking at here is 42
# The distict zone we are looking at here is 24
# The distict zone we are looking at here is 36
# The distict zone we are looking at here is 11
# The distict zone we are looking at here is 6
# The distict zone we are looking at here is 18
# The distict zone we are looking at here is 4
# The distict zone we are looking at here is 40
# The distict zone we are looking at here is 19
# The distict zone we are looking at here is 49
# The distict zone we are looking at here is 33
# The distict zone we are looking at here is 26
# The distict zone we are looking at here is 3
# The distict zone we are looking at here is 13
# The distict zone we are looking at here is 39
# The distict zone we are looking at here is 45
# The distict zone we are looking at here is 12
# The distict zone we are looking at here is 38
# The distict zone we are looking at here is 1
# The distict zone we are looking at here is 32
# The distict zone we are looking at here is 10
# The distict zone we are looking at here is 20
# The distict zone we are looking at here is 22
# The distict zone we are looking at here is 21
# The distict zone we are looking at here is 23
# The distict zone we are looking at here is 50
# The distict zone we are looking at here is 46
# The distict zone we are looking at here is 44
# The distict zone we are looking at here is 25

# %%
test = df.loc[df['council_district']==48]
test
Total_e_l = test['extremely_low_income_units'].sum()
print (Total_e_l)
Total_v_l = test['very_low_income_units'].sum()
print (Total_v_l)
Total_l = test['low_income_units'].sum()
print (Total_l)
Total_mo = test['moderate_income_units'].sum()
print (Total_mo)
Total_mid = test['middle_income_units'].sum()
print (Total_mid)
df2 = pd.DataFrame({'total': [Total_e_l, Total_v_l,Total_l,Total_mo,Total_mid]},index=['extremely_low_income_units', 'very_low_income_units','low_income_units','moderate_income_units','middle_income_units'])
plot = df2.plot.pie(y='total', figsize=(5, 5))
# Out:
# 896
# 0
# 0
# 0
# 193

# %%
zipe = df.postcode.unique()
print(zipe)
#for i in zipe:
ne = df.nta_-_neighborhood_tabulation_area.unique()
# Out:
# [10037. 10032. 11206. 11433. 11224. 10473. 10026. 10030. 10031. 11235.
#  10453. 10455. 10459. 11691. 10009. 10002. 11212. 10452. 11208. 10456.
#  11214. 11211. 11237. 10460. 10474. 11434. 11238. 10457. 10128. 10027.
#  10454. 11233. 11207. 11435. 10458. 11213.    nan 10024. 10472. 11249.
#  10029. 10036. 11218. 11226. 11358. 10467. 11432. 10025. 11221. 10035.
#  11239. 10304. 11222. 11101. 11216. 11225. 10463. 10461. 10462. 11412.
#  11423. 10001. 11201. 11229. 10466. 10028. 11232. 10468. 10022. 11693.
#  11205. 11429. 11420. 11436. 11417. 11413. 10019. 11220. 11217. 11377.
#  10010. 11223. 10451. 10014. 11355. 11102. 11369. 10301. 10021. 10011.
#  11203. 11419. 11411. 11692. 11215. 10023. 10069. 11427. 10034. 10471.
#  11368. 10016. 10033. 11105. 10314. 11231. 10039. 11236. 11422. 10303.
#  11210. 10012. 11106. 10018. 10003. 10017. 10038. 10158. 11230. 10013.]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-5d36a2207bdc> in <module>
#       3 print(zipe)
#       4 #for i in zipe:
# ----> 5 ne = df.nta_-_neighborhood_tabulation_area.unique()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'nta_'
